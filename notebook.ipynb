# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import random
import kmax as kx
import utility as util

# %%
# Test setup
n = 20
G = nx.complete_graph(n)

# Add random edge weights
for e in G.edges:
    G[e[0]][e[1]]["weight"] = random.uniform(0,1)

kmax = kx.generate_kmax(G, 1)

# %%
# Drawing
plt.figure(1)
kx.custom_draw(kmax, "kmax.png")

plt.figure(2)
kx.custom_draw(G, "G.png", draw_edge_weights=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 kx.custom_draw(kmax, "kmax.png")
#       5 plt.figure(2)
# ----> 6 kx.custom_draw(G, "G.png", draw_edge_weights=False, arrows=True)
#
# TypeError: custom_draw() got an unexpected keyword argument 'arrows'

# %%
#Diameter
print(util.kmax_diameter(kmax))
# Out:
# not sure what to put here yet so I just summed the diameter of the connected components
# 11
