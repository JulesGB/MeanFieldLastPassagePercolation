# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import random
import kmax as kx
import utility as util

# %%
# Test setup
n = 20
G = nx.complete_graph(n)

# Add random edge weights
for e in G.edges:
    G[e[0]][e[1]]["weight"] = random.uniform(0,1)

kmax = kx.generate_kmax(G, 1)

# %%
# Drawing
plt.figure(1)
kx.custom_draw(kmax, "kmax.png")

plt.figure(2)
kx.custom_draw(G, "G.png", draw_edge_weights=False)

# %%
#Diameter
print(util.kmax_diameter(kmax))
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Diameter
# ----> 2 print(util.kmax_diameter(kmax))
#
# File c:\Users\Charles\OneDrive\Desktop\MeanField\MeanFieldLastPassagePercolation\utility.py:11, in kmax_diameter(graph)
#       9 else:
#      10     sum = 0
# ---> 11     S = [graph.subgraph(c).copy() for c in nx.weakly_connected_components(graph)]
#      12     for sub in S:
#      13         sum += nx.diameter(sub)
#
# File c:\Users\Charles\AppData\Local\Programs\Python\Python312\Lib\site-packages\networkx\utils\decorators.py:789, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     788 def func(*args, __wrapper=None, **kwargs):
# --> 789     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 26:3, in argmap_weakly_connected_components_22(G, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File c:\Users\Charles\AppData\Local\Programs\Python\Python312\Lib\site-packages\networkx\utils\decorators.py:92, in not_implemented_for.<locals>._not_implemented_for(g)
#      88 def _not_implemented_for(g):
#      89     if (mval is None or mval == g.is_multigraph()) and (
#      90         dval is None or dval == g.is_directed()
#      91     ):
# ---> 92         raise nx.NetworkXNotImplemented(errmsg)
#      94     return g
#
# NetworkXNotImplemented: not implemented for undirected type
